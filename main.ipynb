# %%
#creating variables for account name, access key and container's name
storage_account_name = "shiv007"
storage_account_access_key = "Your_Storage_Access_Key"
container_name = "at2"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Mounting all the data from the Azure blob storage into DBFS
dbutils.fs.mount(
  source = f'wasbs://{container_name}@{storage_account_name}.blob.core.windows.net',
  mount_point = f'/mnt/{container_name}/',
  extra_configs = {'fs.azure.account.key.' + storage_account_name + '.blob.core.windows.net': storage_account_access_key}
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1906319146251919&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> dbutils.fs.mount(
# </span><span class="ansi-green-intense-fg ansi-bold">      2</span>   source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">f&#39;wasbs://{container_name}@{storage_account_name}.blob.core.windows.net&#39;</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>   mount_point <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">f&#39;/mnt/{container_name}/&#39;</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>   extra_configs <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">{</span><span class="ansi-blue-fg">&#39;fs.azure.account.key.&#39;</span> <span class="ansi-blue-fg">+</span> storage_account_name <span class="ansi-blue-fg">+</span> <span class="ansi-blue-fg">&#39;.blob.core.windows.net&#39;</span><span class="ansi-blue-fg">:</span> storage_account_access_key<span class="ansi-blue-fg">}</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> )
#
# <span class="ansi-green-fg">/databricks/python_shell/dbruntime/dbutils.py</span> in <span class="ansi-cyan-fg">f_with_exception_handling</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    387</span>                     exc<span class="ansi-blue-fg">.</span>__context__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    388</span>                     exc<span class="ansi-blue-fg">.</span>__cause__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-fg">--&gt; 389</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">raise</span> exc
# <span class="ansi-green-intense-fg ansi-bold">    390</span>
# <span class="ansi-green-intense-fg ansi-bold">    391</span>             <span class="ansi-green-fg">return</span> f_with_exception_handling
#
# <span class="ansi-red-fg">ExecutionError</span>: An error occurred while calling o406.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/at2; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/at2
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:128)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:68)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.createOrUpdateMount(DBUtilsCore.scala:756)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.mount(DBUtilsCore.scala:776)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/at2
# 	at scala.Predef$.require(Predef.scala:281)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$insertMount$1(MetadataManager.scala:468)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$modifyAndVerify$1(MetadataManager.scala:833)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.withRetries(MetadataManager.scala:614)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.modifyAndVerify(MetadataManager.scala:822)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.insertMount(MetadataManager.scala:476)
# 	at com.databricks.backend.daemon.data.server.handler.MountHandler.receive(MountHandler.scala:114)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1(SessionContext.scala:54)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1$adapted(SessionContext.scala:53)
# 	at scala.collection.immutable.List.foreach(List.scala:431)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.queryHandlers(SessionContext.scala:53)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$4.applyOrElse(DbfsServerBackend.scala:345)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$4.applyOrElse(DbfsServerBackend.scala:304)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$2(ServerBackend.scala:120)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:147)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:147)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$1(ServerBackend.scala:102)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:515)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:609)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:630)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:377)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:108)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:375)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:372)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:24)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:420)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:405)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:24)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:604)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:524)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:24)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:515)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:487)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:24)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:101)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleRPC$2(JettyServer.scala:976)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:976)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala

# %% [markdown]
# ##PART 1

# %%
#importing the required libraries
import pandas as pd
import numpy as np
import glob 
import os
import pyarrow.parquet as pq
import datetime
from pyspark.sql.functions import *
import pyspark.sql.functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#To check the contents mounted into the yellow taxi directory where airport fees is of type double
dbutils.fs.ls("/mnt/at2/yellow/double")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[406]: [FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/csv_file/&#39;, name=&#39;csv_file/&#39;, size=0, modificationTime=1663741180000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2020-08.parquet&#39;, name=&#39;yellow_tripdata_2020-08.parquet&#39;, size=16601463, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2020-09.parquet&#39;, name=&#39;yellow_tripdata_2020-09.parquet&#39;, size=21381938, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2020-11.parquet&#39;, name=&#39;yellow_tripdata_2020-11.parquet&#39;, size=23583368, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2020-12.parquet&#39;, name=&#39;yellow_tripdata_2020-12.parquet&#39;, size=23020036, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-01.parquet&#39;, name=&#39;yellow_tripdata_2021-01.parquet&#39;, size=21686067, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-02.parquet&#39;, name=&#39;yellow_tripdata_2021-02.parquet&#39;, size=21777258, modificationTime=1663678496000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-03.parquet&#39;, name=&#39;yellow_tripdata_2021-03.parquet&#39;, size=30007852, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-04.parquet&#39;, name=&#39;yellow_tripdata_2021-04.parquet&#39;, size=34018560, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-05.parquet&#39;, name=&#39;yellow_tripdata_2021-05.parquet&#39;, size=38743682, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-06.parquet&#39;, name=&#39;yellow_tripdata_2021-06.parquet&#39;, size=44071592, modificationTime=1663678496000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-07.parquet&#39;, name=&#39;yellow_tripdata_2021-07.parquet&#39;, size=43697690, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-08.parquet&#39;, name=&#39;yellow_tripdata_2021-08.parquet&#39;, size=43425907, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-09.parquet&#39;, name=&#39;yellow_tripdata_2021-09.parquet&#39;, size=46125883, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-10.parquet&#39;, name=&#39;yellow_tripdata_2021-10.parquet&#39;, size=53286464, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-11.parquet&#39;, name=&#39;yellow_tripdata_2021-11.parquet&#39;, size=53100722, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2021-12.parquet&#39;, name=&#39;yellow_tripdata_2021-12.parquet&#39;, size=49639052, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2022-01.parquet&#39;, name=&#39;yellow_tripdata_2022-01.parquet&#39;, size=38139949, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2022-02.parquet&#39;, name=&#39;yellow_tripdata_2022-02.parquet&#39;, size=45616512, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2022-03.parquet&#39;, name=&#39;yellow_tripdata_2022-03.parquet&#39;, size=55682369, modificationTime=1663678497000),
#  FileInfo(path=&#39;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2022-04.parquet&#39;, name=&#39;yellow_tripdata_2022-04.parquet&#39;, size=55222692, modificationTime=1663678497000)]</div>

# %%
#reading the yellow taxi into two seperate variables one for double and the other for integer type airport fees
df1 = spark.read.parquet('dbfs:/mnt/at2/yellow/double/*.parquet')
df2 = spark.read.parquet('dbfs:/mnt/at2/yellow/integer')
df2.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[407]: 103928335</div>

# %%
#changing the data type of the airport fee column to double for all yellow taxi datasets 
df2 = df2.withColumn("airport_fee",df2.airport_fee.cast('double'))
df2.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[408]: 103928335</div>

# %%
#merging all the yellow taxi datasets into one
df3 = df1.unionByName(df2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#counting the total number of rows for all the yellow taxi data
df3.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[410]: 152823008</div>

# %%
#Two temporary columns created
df3 = df3.withColumn("suma", col("fare_amount")+col("extra")+col("mta_tax")+col("tip_amount")+col("tolls_amount")+col("improvement_surcharge"))
df3 = df3.withColumn("sumb", col("total_amount")+col("airport_fee")+col("congestion_surcharge"))

#Adding  airport_fee and congestion_surcharge to total_amount where they weren't added
df3 = df3.withColumn('final_sum', F.when(F.col('total_amount') == F.col('suma'),col("sumb")).otherwise(df3.total_amount))
df3 = df3.drop('total_amount')
df3 = df3.withColumnRenamed("final_sum","total_amount")
df3 = df3.drop('final_sum', 'suma', 'sumb')

# %%
#changing column names, dropping the airport_fee column and adding a colour column
df3 = df3.withColumnRenamed("tpep_pickup_datetime","pickup_datetime")
df3 = df3.withColumnRenamed("tpep_dropoff_datetime","dropoff_datetime")
df3 = df3.drop("airport_fee")
df3.printSchema()
df3 = df3.withColumn("Colour", lit("yellow"))
df3.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
#
# Out[411]: 152823008</div>

# %%
# reading the green taxi data, removing extra columns, renaming some columns and chaning the datatype of the "payment_type" column to "long"
dfg = spark.read.parquet("dbfs:/mnt/at2/green")
dfg = dfg.withColumnRenamed("lpep_pickup_datetime","pickup_datetime")
dfg = dfg.withColumnRenamed("lpep_dropoff_datetime","dropoff_datetime")
dfg = dfg.withColumn("payment_type",dfg.payment_type.cast('long'))
dfg = dfg.drop("ehail_fee","trip_type")
dfg = dfg.withColumn("Colour", lit("green"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- Colour: string (nullable = false)
#
# </div>

# %%
# counting the number of rows for all the green taxi data
dfg.count()

# %%
#merging the yellow and the green taxi datasets into one 
df3 = df3.unionByName(dfg)

df3.printSchema()

# %%
df = spark.read.parquet("dbfs:/mnt/at2/yellow/double/yellow_tripdata_2022-04.parquet")
df.write.csv("dbfs:/mnt/at2/yellow/double/csv_file")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2613438548895858&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> f <span class="ansi-blue-fg">=</span> spark<span class="ansi-blue-fg">.</span>read<span class="ansi-blue-fg">.</span>parquet<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dbfs:/mnt/at2/yellow/double/yellow_tripdata_2022-04.parquet&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>csv<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dbfs:/mnt/at2/yellow/double/csv_file&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;df&#39; is not defined</div>

# %%
#select all the data where passenger_count is not greater than 5
df3 = df3.filter(df3.passenger_count<6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Removing trips that are finishing before the starting time
df3 = df3.filter(df3.dropoff_datetime > df3.pickup_datetime)

#filtering all the data between January 2019 to April 2022
df3 = df3.filter(df3.pickup_datetime < "2022-05-01 00:00:00")
df3 = df3.filter(df3.pickup_datetime > "2018-12-31 23:59:59")

#Removing all the trips where dropoff_datetime doesn't lie in between January 2019 and April 2022
df3 = df3.filter(df3.dropoff_datetime < "2022-05-01 10:00:00")
df3 = df3.filter(df3.dropoff_datetime > "2018-12-31 23:59:59")
df3.count()
df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- Colour: string (nullable = false)
#
# </div>

# %%
df3 = df3.withColumn('DiffInSeconds',col("dropoff_datetime").cast("long") - col('pickup_datetime').cast("long"))
df3 = df3.withColumn('DiffInHours',round(col('DiffInSeconds')/3600, 2))
df3 = df3.withColumn('Speed', round(col("trip_distance")/col("DiffInHours"),2))
df3.show()
df3.count()
df3.printSchema()

# %%
#removing all the trips with negative speed
df3 = df3.filter(df3.Speed > 0)
df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- Colour: string (nullable = false)
# -- DiffInSeconds: long (nullable = true)
# -- DiffInHours: double (nullable = true)
# -- Speed: double (nullable = true)
#
# </div>

# %%
#removing trips with very high average speed
df3 = df3.filter(df3.Speed < 55)
df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- Colour: string (nullable = false)
# -- DiffInSeconds: long (nullable = true)
# -- DiffInHours: double (nullable = true)
# -- Speed: double (nullable = true)
#
# </div>

# %%
#Removing all the trips below the duration of 2 minutes and above the duration of 10 hours
df3 = df3.filter(df3.DiffInSeconds > 120 )
df3 = df3.filter(df3.DiffInSeconds < 36000)
df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- Colour: string (nullable = false)
# -- DiffInSeconds: long (nullable = true)
# -- DiffInHours: double (nullable = true)
# -- Speed: double (nullable = true)
#
# </div>

# %%
#Removing trips shorter than 0.06 miles and longer than 50 miles
df3 = df3.filter(df3.trip_distance > 0.06 )
df3 = df3.filter(df3.trip_distance < 50)
df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- Colour: string (nullable = false)
# -- DiffInSeconds: long (nullable = true)
# -- DiffInHours: double (nullable = true)
# -- Speed: double (nullable = true)
#
# </div>

# %%
#removing negative tip_amount values from the data
df3 = df3.filter(df3.tip_amount >= 0)
df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: long (nullable = true)
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- PULocationID: long (nullable = true)
# -- DOLocationID: long (nullable = true)
# -- payment_type: long (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- Colour: string (nullable = false)
# -- DiffInSeconds: long (nullable = true)
# -- DiffInHours: double (nullable = true)
# -- Speed: double (nullable = true)
#
# </div>

# %%
#writing the final data into DBFS
df3.repartition(1).write.mode("overwrite").format('parquet').save('dbfs:/mnt/at2/final_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ##PART 2

# %%
#reading the parquet file of the data
d = spark.read.parquet('dbfs:/mnt/at2/final_data/*.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#converting the parquet file into a table called table_1 into DBFS
d.write.saveAsTable("Table_1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1688024563968370&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>d<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;Table_1&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">saveAsTable</span><span class="ansi-blue-fg">(self, name, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    804</span>         <span class="ansi-green-fg">if</span> format <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    805</span>             self<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>format<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 806</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    807</span>
# <span class="ansi-green-intense-fg ansi-bold">    808</span>     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Table default.Table_1 already exists</div>

# %%
# %sql
/*calculating the total number of trips, day of week having the most trips, hour of the day having the most trips, average passengers, average amount paid per trip and average amount paid per person for a each specific year and month*/
SELECT year, month, No_of_Trips, Week_day, Hour_of_the_Day, avg_passenger_count, avg_amt_per_trip, avg_amt_per_person from
(
select
year, month, No_of_Trips, Week_day, Hour_of_the_Day,  avg_passenger_count, avg_amt_per_trip, avg_amt_per_person ,rank() OVER (PARTITION BY Year, Month ORDER BY No_of_Trips DESC) AS RK from 
  (
  select count(*) AS No_of_Trips, dayofweek(pickup_datetime) as Week_day, hour(pickup_datetime) as Hour_of_the_Day, YEAR(pickup_datetime) AS Year, MONTH(pickup_datetime) AS Month, round(avg(passenger_count),2) as avg_passenger_count, round(avg(total_amount),2) as avg_amt_per_trip, round(avg(total_amount)/avg(passenger_count),2) as avg_amt_per_person  from table_1
  GROUP BY YEAR(pickup_datetime), MONTH(pickup_datetime), hour(pickup_datetime), dayofweek(pickup_datetime)
  Order by YEAR(pickup_datetime), MONTH(pickup_datetime)
  )) where rk = 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>month</th><th>No_of_Trips</th><th>Week_day</th><th>Hour_of_the_Day</th><th>avg_passenger_count</th><th>avg_amt_per_trip</th><th>avg_amt_per_person</th></tr></thead><tbody><tr><td>2019</td><td>1</td><td>96067</td><td>5</td><td>18</td><td>1.43</td><td>15.85</td><td>11.1</td></tr><tr><td>2019</td><td>2</td><td>77568</td><td>6</td><td>18</td><td>1.45</td><td>18.08</td><td>12.5</td></tr><tr><td>2019</td><td>3</td><td>93832</td><td>6</td><td>18</td><td>1.46</td><td>18.82</td><td>12.93</td></tr><tr><td>2019</td><td>4</td><td>93026</td><td>3</td><td>18</td><td>1.44</td><td>18.65</td><td>12.99</td></tr><tr><td>2019</td><td>5</td><td>90210</td><td>5</td><td>18</td><td>1.44</td><td>19.7</td><td>13.68</td></tr><tr><td>2019</td><td>6</td><td>67419</td><td>7</td><td>17</td><td>1.53</td><td>18.58</td><td>12.14</td></tr><tr><td>2019</td><td>7</td><td>75869</td><td>3</td><td>18</td><td>1.44</td><td>18.79</td><td>13.09</td></tr><tr><td>2019</td><td>8</td><td>72567</td><td>5</td><td>18</td><td>1.44</td><td>19.56</td><td>13.58</td></tr><tr><td>2019</td><td>9</td><td>68122</td><td>5</td><td>19</td><td>1.42</td><td>19.43</td><td>13.65</td></tr><tr><td>2019</td><td>10</td><td>85036</td><td>4</td><td>18</td><td>1.42</td><td>19.52</td><td>13.78</td></tr><tr><td>2019</td><td>11</td><td>80896</td><td>6</td><td>18</td><td>1.45</td><td>19.11</td><td>13.13</td></tr><tr><td>2019</td><td>12</td><td>71556</td><td>3</td><td>18</td><td>1.44</td><td>19.05</td><td>13.2</td></tr><tr><td>2020</td><td>1</td><td>79742</td><td>5</td><td>18</td><td>1.4</td><td>18.52</td><td>13.22</td></tr><tr><td>2020</td><td>2</td><td>72676</td><td>6</td><td>18</td><td>1.41</td><td>18.5</td><td>13.09</td></tr><tr><td>2020</td><td>3</td><td>34162</td><td>2</td><td>18</td><td>1.35</td><td>18.34</td><td>13.57</td></tr><tr><td>2020</td><td>4</td><td>3062</td><td>4</td><td>15</td><td>1.23</td><td>15.43</td><td>12.57</td></tr><tr><td>2020</td><td>5</td><td>4292</td><td>6</td><td>17</td><td>1.19</td><td>17.42</td><td>14.61</td></tr><tr><td>2020</td><td>6</td><td>7014</td><td>3</td><td>15</td><td>1.28</td><td>17.18</td><td>13.38</td></tr><tr><td>2020</td><td>7</td><td>10228</td><td>5</td><td>14</td><td>1.28</td><td>16.11</td><td>12.57</td></tr><tr><td>2020</td><td>8</td><td>11789</td><td>2</td><td>14</td><td>1.32</td><td>16.1</td><td>12.16</td></tr><tr><td>2020</td><td>9</td><td>17490</td><td>4</td><td>15</td><td>1.33</td><td>16.65</td><td>12.49</td></tr><tr><td>2020</td><td>10</td><td>21525</td><td>5</td><td>15</td><td>1.36</td><td>16.97</td><td>12.47</td></tr><tr><td>2020</td><td>11</td><td>18973</td><td>2</td><td>15</td><td>1.33</td><td>16.21</td><td>12.21</td></tr><tr><td>2020</td><td>12</td><td>21345</td><td>3</td><td>14</td><td>1.32</td><td>16.22</td><td>12.26</td></tr><tr><td>2021</td><td>1</td><td>17081</td><td>6</td><td>15</td><td>1.32</td><td>16.22</td><td>12.26</td></tr><tr><td>2021</td><td>2</td><td>17002</td><td>6</td><td>18</td><td>1.35</td><td>17.27</td><td>12.81</td></tr><tr><td>2021</td><td>3</td><td>24668</td><td>4</td><td>17</td><td>1.31</td><td>17.56</td><td>13.44</td></tr><tr><td>2021</td><td>4</td><td>27824</td><td>6</td><td>14</td><td>1.32</td><td>17.09</td><td>12.94</td></tr><tr><td>2021</td><td>5</td><td>26906</td><td>7</td><td>17</td><td>1.43</td><td>17.68</td><td>12.38</td></tr><tr><td>2021</td><td>6</td><td>34922</td><td>4</td><td>18</td><td>1.34</td><td>18.82</td><td>14.09</td></tr><tr><td>2021</td><td>7</td><td>33542</td><td>5</td><td>18</td><td>1.35</td><td>19.78</td><td>14.62</td></tr><tr><td>2021</td><td>8</td><td>34180</td><td>3</td><td>18</td><td>1.35</td><td>18.86</td><td>13.95</td></tr><tr><td>2021</td><td>9</td><td>36795</td><td>4</td><td>18</td><td>1.33</td><td>18.95</td><td>14.25</td></tr><tr><td>2021</td><td>10</td><td>41834</td><td>6</td><td>18</td><td>1.37</td><td>19.73</td><td>14.45</td></tr><tr><td>2021</td><td>11</td> ...

# %%
# %sql
/*calculating the average, median, minimum and maximum trip duration, distance and speed*/
select colour, round(avg(DiffInSeconds/60),2) as Average_TripDuration, 
       round(min(DiffInSeconds/60),2) as Minimum_TripDuration,
       round(max(DiffInSeconds/60),2) as Maximum_TripDuration,
       round(PERCENTILE_CONT(0.5) WITHIN GROUP (ORDER BY DiffInSeconds/60),2) as Median_TripDuration,
       round(avg(trip_distance*1.609),2) as Average_TripDistance,
       round(min(trip_distance*1.609),2) as Minimum_TripDistance,
       round(max(trip_distance*1.609),2) as Maximum_TripDistance,
       round(PERCENTILE_CONT(0.5) WITHIN GROUP (ORDER BY trip_distance*1.609),2) as Median_TripDistance,
       round(avg(Speed*1.609),2) as Average_Speed,
       round(min(Speed*1.609),2) as Minimum_Speed,
       round(max(Speed*1.609),2) as Maximum_Speed,
       round(PERCENTILE_CONT(0.5) WITHIN GROUP (ORDER BY Speed*1.609),2) as Median_Speed
from table_1
group by colour;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>colour</th><th>Average_TripDuration</th><th>Minimum_TripDuration</th><th>Maximum_TripDuration</th><th>Median_TripDuration</th><th>Average_TripDistance</th><th>Minimum_TripDistance</th><th>Maximum_TripDistance</th><th>Median_TripDistance</th><th>Average_Speed</th><th>Minimum_Speed</th><th>Maximum_Speed</th><th>Median_Speed</th></tr></thead><tbody><tr><td>yellow</td><td>14.29</td><td>2.02</td><td>599.97</td><td>11.17</td><td>4.89</td><td>0.11</td><td>80.43</td><td>2.74</td><td>18.71</td><td>0.02</td><td>88.48</td><td>16.09</td></tr><tr><td>green</td><td>15.16</td><td>2.02</td><td>599.98</td><td>11.3</td><td>5.13</td><td>0.11</td><td>80.29</td><td>3.11</td><td>19.4</td><td>0.02</td><td>88.46</td><td>17.35</td></tr></tbody></table></div>

# %%
# %sql
/*calculating the percentage of trips where drivers received tips*/
Select round((
select count(tip_amount) 
from table_1
where tip_amount > 0)
/count(tip_amount)*100, 2) AS no_of_t
from table_1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>no_of_t</th></tr></thead><tbody><tr><td>70.13</td></tr></tbody></table></div>

# %%
# %sql
/*calculating the percentage of trips where the tips received by the drivers was greater than $10 */
Select round((
select count(tip_amount) 
from table_1
where tip_amount > 9)
/count(tip_amount)*100, 2) AS no_of_t
from table_1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>no_of_t</th></tr></thead><tbody><tr><td>2.94</td></tr></tbody></table></div>

# %%
# %sql
/*calculating average speed and average distance covered per kilometer for different bins of duration*/
With table2 as
(
SELECT
     CASE 
        WHEN DiffInSeconds/60 < 5 THEN 'Under_5_mins'
        WHEN DiffInSeconds/60 >= 5 AND DiffInSeconds/60 <= 10 THEN '5_To_10mins'
        WHEN DiffInSeconds/60 > 10 AND DiffInSeconds/60 <= 20 THEN '10_To_20mins'
        WHEN DiffInSeconds/60 > 20 AND DiffInSeconds/60 <= 30 THEN '20_To_30mins'
        WHEN DiffInSeconds/60 > 30 AND DiffInSeconds/60 <= 60 THEN '30_To_60mins'
        WHEN DiffInSeconds/60 > 60 THEN 'At_least_60mins'
    End as BinsOfDurations,
    Speed, trip_distance, total_amount
FROM
    table_1
)
SELECT
    BinsOfDurations,
    count(*) AS No_Of_Trips, round((avg(Speed)*1.609), 2) as Avg_Speed_KMPH, ROUND(sum((trip_distance)*1.609)/sum(total_amount), 2) AS Avg_DistanceKm_perDollar
FROM
    table2
GROUP BY
    BinsOfDurations;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BinsOfDurations</th><th>No_Of_Trips</th><th>Avg_Speed_KMPH</th><th>Avg_DistanceKm_perDollar</th></tr></thead><tbody><tr><td>At_least_60mins</td><td>1263951</td><td>23.07</td><td>0.4</td></tr><tr><td>Under_5_mins</td><td>19674997</td><td>18.95</td><td>0.13</td></tr><tr><td>30_To_60mins</td><td>10765267</td><td>27.32</td><td>0.37</td></tr><tr><td>20_To_30mins</td><td>18456627</td><td>21.57</td><td>0.3</td></tr><tr><td>5_To_10mins</td><td>45955904</td><td>16.84</td><td>0.18</td></tr><tr><td>10_To_20mins</td><td>53388409</td><td>17.51</td><td>0.24</td></tr></tbody></table></div>

# %% [markdown]
# ##PART 3

# %%
#reading the data into a variable dna to ready it up for machine learning 
dna = df3
dna = dna.drop("DiffInHours","Speed","Colour","store_and_fwd_flag","VendorID","tore_and_fwd_flag", "Fare_amount", "PULocationID", "DOLocationID", "Trip_type")
dna.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- payment_type: long (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- DiffInSeconds: long (nullable = true)
#
# </div>

# %%
#creating three new columns as month, year and day
dna = dna.withColumn('month',month(dna.pickup_datetime))
dna = dna.withColumn('year',year(dna.pickup_datetime))
dna = dna.withColumn('day',dayofmonth(dna.pickup_datetime))
dna.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- pickup_datetime: timestamp (nullable = true)
# -- dropoff_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- payment_type: long (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- DiffInSeconds: long (nullable = true)
# -- month: integer (nullable = true)
# -- year: integer (nullable = true)
# -- day: integer (nullable = true)
#
# </div>

# %%
#casting the data type of column payment_type to "long and removing all the unpredictable value columns"
dna = dna.withColumn("payment_type", dna.payment_type.cast('long'))
ls= ["1","2","5"]
dna = dna.filter(dna.payment_type.isin(ls))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Removing the column "dropoff_datetime"
dna = dna.drop("dropoff_datetime" )
dna.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- pickup_datetime: timestamp (nullable = true)
# -- passenger_count: double (nullable = true)
# -- trip_distance: double (nullable = true)
# -- RatecodeID: double (nullable = true)
# -- payment_type: long (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# -- improvement_surcharge: double (nullable = true)
# -- total_amount: double (nullable = true)
# -- congestion_surcharge: double (nullable = true)
# -- DiffInSeconds: long (nullable = true)
# -- month: integer (nullable = true)
# -- year: integer (nullable = true)
# -- day: integer (nullable = true)
#
# </div>

# %%
#Removing the column payment_type
dna = dna.drop("payment_type")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#replacing '-' with '_' in the entire dataset
for col in dna.columns:
    dna = dna.withColumnRenamed(col, col.strip().replace('-', '_'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dna1 = dna.filter(dna.pickup_datetime < "2022-04-01 00:00:00")
dna1 = dna1.drop("pickup_datetime")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
colz = ['DiffInSeconds','passenger_count','RatecodeID','month','year', 'day', 'mta_tax','trip_distance','extra','tolls_amount', 'improvement_surcharge', 'congestion_surcharge','tip_amount']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
num_cols = ['DiffInSeconds','trip_distance','extra','tolls_amount', 'improvement_surcharge', 'congestion_surcharge','tip_amount']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
total_amount = ['total_amount']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cat_cols = ['passenger_count','RatecodeID','month','year', 'day', 'mta_tax']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dna1.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- passenger_count: double (nullable = false)
# -- trip_distance: double (nullable = false)
# -- RatecodeID: double (nullable = false)
# -- extra: double (nullable = false)
# -- mta_tax: double (nullable = false)
# -- tip_amount: double (nullable = false)
# -- tolls_amount: double (nullable = false)
# -- improvement_surcharge: double (nullable = false)
# -- total_amount: double (nullable = false)
# -- congestion_surcharge: double (nullable = false)
# -- DiffInSeconds: long (nullable = true)
# -- month: integer (nullable = true)
# -- year: integer (nullable = true)
# -- day: integer (nullable = true)
#
# </div>

# %% [markdown]
# ##GRADIENT-BOOSTED TREE REGRESSOR

# %%
#importing the required libraries 
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline, PipelineModel
from pyspark.ml.tuning import ParamGridBuilder
from pyspark.ml.feature import StringIndexer, VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stages = []
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#applying string indexer over the categorical value columns
for cat_col in cat_cols:

    col_indexer = StringIndexer(inputCol=cat_col, outputCol=f"{cat_col}_ind")

    stages += [col_indexer]


cat_cols_ind = [f"{cat_col}_ind" for cat_col in cat_cols]
cat_cols_ind = [x.replace('_ind', '') for x in cat_cols_ind]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Applying GB Tree Regressor
regressor = GBTRegressor(featuresCol = 'features', labelCol = "total_amount")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Using Vector assembler and creating a pipeline
assembler = VectorAssembler(inputCols=cat_cols_ind + num_cols, outputCol="features")
pipeline  = Pipeline(stages = [assembler,regressor])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#fitting the data through pipeline in the model
pipeline_model = pipeline.fit(dna1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#saving the pipeline
pipeline_model.write().overwrite().save("pipeline_save")
pipeline_Model = PipelineModel.load('dbfs:/pipeline_save')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#testing over different number of iterations
paramGrid = ParamGridBuilder().addGrid(regressor.maxIter,[5, 10, 20]).build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#splitting the data into train and test in tehe ratio of 80% isto 20%
train_data , test_data = dna1.randomSplit([0.8,0.2], seed = 123)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#applying cross validation over 3 folds
from pyspark.ml.tuning import CrossValidator
crossval = CrossValidator(estimator = pipelineModel,
                         estimatorParamMaps = paramGrid,
                         evaluator = RegressionEvaluator(labelCol = "total_amount"),
                         numFolds = 3)

crossval
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[448]: CrossValidator_6577732e76f5</div>

# %%
#fitting the cross-validated model
cvModel1 = crossval.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#fitting the best model
bestModel = cvModel1.bestModel
print(bestModel.stages)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[VectorAssembler_19a1cb0d5cd8, RandomForestRegressionModel: uid=RandomForestRegressor_ef7c1e3dd33f, numTrees=500, numFeatures=12]
# </div>

# %%
#drawing predictions over test data
pred = cvModel1.transform(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#calculating RMSE
eval = RegressionEvaluator(labelCol = 'total_amount')
rmse = eval.evaluate(pred, {eval.metricName:'rmse'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#printing RMSE
print("RMSE: %.3f" %rmse)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ##RANDOM FOREST CLASSIFIER

# %%
from pyspark.ml.regression import RandomForestRegressor
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
stages = []
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
for cat_col in cat_cols:

    col_indexer = StringIndexer(inputCol=cat_col, outputCol=f"{cat_col}_ind")

    stages += [col_indexer]


cat_cols_ind = [f"{cat_col}_ind" for cat_col in cat_cols]
cat_cols_ind = [x.replace('_ind', '') for x in cat_cols_ind]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
regressor = RandomForestRegressor(featuresCol = "features",labelCol = "total_amount")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
assembler = VectorAssembler(inputCols=cat_cols_ind + num_cols, outputCol="features")
pipeline  = Pipeline(stages = [assembler,regressor])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
pipeline_modelrf = pipeline.fit(dna1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
pipeline_modelrf.write().overwrite().save("pipeline_save_rf")
pipeline_Modelrf = Pipeline.load('dbfs:/pipeline_save_rf')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
paramGrid = ParamGridBuilder().addGrid(regressor.numTrees,[100,500]) .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
train_data , test_data = dna1.randomSplit([0.8,0.2], seed = 123)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.ml.tuning import CrossValidator
crossval = CrossValidator(estimator = pipelineModel,
                         estimatorParamMaps = paramGrid,
                         evaluator = RegressionEvaluator(labelCol = "total_amount"),
                         numFolds = 3)

crossval
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
cvModel = crossval.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
bestModel = cvModel.bestModel
print(bestModel.stages)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
pred = cvModel.transform(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
eval = RegressionEvaluator(labelCol = 'total_amount')
rmse = eval.evaluate(pred, {eval.metricName:'rmse'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
print("RMSE: %.3f" %rmse)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ##Predicting April 2022

# %%
#selecting data for only April 2022
dna2 = dna.filter(dna.pickup_datetime > "2022-03-31 23:59:59")
dna2 = dna2.drop("pickup_datetime")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#applying predction using GB Tree model
pred = cvModel1.transform(dna2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Calculating RMSE
eval = RegressionEvaluator(labelCol = 'total_amount')
rmse = eval.evaluate(pred, {eval.metricName:'rmse'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Printing RMSE
print("RMSE: %.3f" %rmse)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import seaborn as sns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Plot actual vs prediction april 2022
dnos = pred.select('total_amount', 'prediction')
pad = dnos.toPandas()
sns.regplot(x="total_amount", y="prediction", data=pad);
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
